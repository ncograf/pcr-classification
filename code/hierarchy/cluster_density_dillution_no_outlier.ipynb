# %%
import numpy as np
import pandas as pd
import data_lib
import plot_lib
import decision_lib
from sklearn import cluster, mixture
import validation_lib
import transform_lib

np.random.seed(200)

# %%
# print available data summary
_ = data_lib.explore_datasets(datafolder="../../Data",verbose=True)
print(data_lib.LABELS_LIST)
# Out:
# ----------------------------------------------------------------------------------------------
# -- The following 4 groups were found
# -- They contain 40 datasets
# -- The first printed entity is the key to the returned dictionary
# -----------------------------------
# Group: ../../Data/6P-positive-dilution-series-2-labelled/droplet-level-data/RawData
# po-di-se-2-A4, files: 13                po-di-se-2-C4, files: 13                po-di-se-2-A1, files: 13
# po-di-se-2-B1, files: 13                po-di-se-2-D1, files: 13                po-di-se-2-B4, files: 13
# po-di-se-2-C1, files: 13                po-di-se-2-D4, files: 13
# -----------------------------------
# Group: ../../Data/6P-positive-dilution-series-1-labelled/droplet-level-data/RawData
# po-di-se-1-D4, files: 13                po-di-se-1-A4, files: 13                po-di-se-1-A1, files: 13
# po-di-se-1-D1, files: 13                po-di-se-1-B1, files: 13                po-di-se-1-C1, files: 13
# po-di-se-1-B4, files: 13                po-di-se-1-C4, files: 13
# -----------------------------------
# Group: ../../Data/6P-positive-dilution-series-labelled/droplet-level-data/RawData
# po-di-se-B8, files: 13                  po-di-se-A8, files: 13                  po-di-se-C8, files: 13
# po-di-se-D8, files: 13
# -----------------------------------
# Group: ../../Data/6P-wastewater-samples-labelled/droplet-level-data/RawData
# wa-sa-A2, files: 13                     wa-sa-B4, files: 13                     wa-sa-C5, files: 13
# wa-sa-C4, files: 13                     wa-sa-B3, files: 13                     wa-sa-B2, files: 13
# wa-sa-A5, files: 13                     wa-sa-A3, files: 13                     wa-sa-C2, files: 13
# wa-sa-C3, files: 13                     wa-sa-D3, files: 13                     wa-sa-D4, files: 13
# wa-sa-B1, files: 13                     wa-sa-A4, files: 13                     wa-sa-A1, files: 13
# wa-sa-D2, files: 13                     wa-sa-D5, files: 13                     wa-sa-C1, files: 13
# wa-sa-B5, files: 13                     wa-sa-D1, files: 13
# -----------------------------------
# ['IAV-M_POS', 'IAV-M_NEG', 'IBV-M_POS', 'IBV-M_NEG', 'MHV_POS', 'MHV_NEG', 'RSV-N_POS', 'RSV-N_NEG', 'SARS-N1_POS', 'SARS-N1_NEG', 'SARS-N2_POS', 'SARS-N2_NEG']

# %% [markdown]
# ### Get samples for negative control

# %%
# load the necessary datasetes
df_di = data_lib.load_dataset(None, [
    "po-di-se-2-A4", "po-di-se-2-B1", "po-di-se-2-C1", "po-di-se-2-C4",
    "po-di-se-2-D1", "po-di-se-2-D4", "po-di-se-2-A1", "po-di-se-2-B4",

    "po-di-se-1-D4", "po-di-se-1-D1", "po-di-se-1-B4", "po-di-se-1-A4",
    "po-di-se-1-B1", "po-di-se-1-C4", "po-di-se-1-A1", "po-di-se-1-C1",

    "po-di-se-B8", "po-di-se-D8", "po-di-se-A8", "po-di-se-C8",
                                     ], 
                              datafolder="../../Data")


df_negative_control = data_lib.load_dataset([],[
    "po-di-se-1-D1", "po-di-se-1-D4",
    "po-di-se-2-D1", "po-di-se-2-D4",
    "po-di-se-D8",
                                                ], 
                                            datafolder="../../Data")
# Everything is positive contol
df_positive_control = df_di.iloc[:,:6]

# convert to numpy
np_di = df_di.to_numpy(copy=True)[:,:6]
np_negative_control = df_negative_control.to_numpy()

# %%
# fix clustering algorithm
prediction_axis = ['SARS-N2_POS','SARS-N1_POS','IBV-M_POS','RSV-N_POS','IAV-M_POS','MHV_POS']
#cluster_engine = cluster.DBSCAN(eps=700, n_jobs=4, min_samples=6, leaf_size=5)
whitening_engine = transform_lib.WhitenTransformer()
num_cluster = int(2**len(prediction_axis) * 2)
cluster_engine = cluster.KMeans(n_clusters=num_cluster, n_init='auto')
#cluster_engine = mixture.GaussianMixture(n_components=100)
decision = decision_lib.ClusterHierarchyDensityClassifier(
                                     negative_control=np_negative_control,
                                     cluster_algorithm=cluster_engine,
                                     whitening_transformer=whitening_engine,
                                     eps=0.25,
                                     contamination=0.004,
                                     outliers=False,
                                     prediction_axis=prediction_axis,
                                     )
df_decision = decision.predict(np_di)

# %% [markdown]
# ## Plot the predictions
#
# - Black = True negative prediction
# - Green = True positive prediciton
# - Purple = False negative
# - Red = False positive
# - yellow = outlier

# %% [markdown]
# #### Plot for all diseases predictions against ground truth
#
# Firs plot is in the decorrelated coordinates, whereas the second is in original coordinates

# %%
df_data_points = pd.DataFrame(data=decision.X, columns=prediction_axis) 
df_predictions = df_decision
df_ground_trouth = df_di
selected_pairs = [
                ('SARS-N2_POS','SARS-N1_POS'),
                ('SARS-N1_POS','SARS-N2_POS'),
                ('IBV-M_POS','RSV-N_POS'),
                ('RSV-N_POS','IBV-M_POS'),
                ('IAV-M_POS','MHV_POS'),
                ('MHV_POS','IAV-M_POS'),
                ]

mask = decision.No_neg_mask
validation_lib.validate_labels(df_di, df_decision)

plot_lib.plot_pairwise_selection_bayesian(
        df_data_points,
        decision.probabilities_df,
        df_ground_trouth,
        selected_pairs,
        n_cols=2,
        mask=mask,
        )
# Out:
# Outlier rate: 0.0, n_outlier: 0
#
# Total error rate: 0.0011799911748272191
#  SARS-N2_POS  SARS-N1_POS  IBV-M_POS  RSV-N_POS  IAV-M_POS  MHV_POS
#     0.000457     0.000986   0.000652   0.004441   0.000133 0.000412
#
# Precision (TP / (TP + FP)): 0.997949645130888
#  SARS-N2_POS  SARS-N1_POS  IBV-M_POS  RSV-N_POS  IAV-M_POS  MHV_POS
#     0.998115     0.994214   0.995921   0.999463   0.999779 0.999929
#
# Recall / TPR (TP / (TP + FN)): 0.9888619522459061
#  SARS-N2_POS  SARS-N1_POS  IBV-M_POS  RSV-N_POS  IAV-M_POS  MHV_POS
#     0.996361     0.994238   0.996789   0.955955   0.998788  0.99536
#
# Specificity / TNR (TN / (TN + FP)): 0.9998000483185302
#  SARS-N2_POS  SARS-N1_POS  IBV-M_POS  RSV-N_POS  IAV-M_POS  MHV_POS
#      0.99983      0.99946   0.999599   0.999943   0.999977 0.999993
#
# Accuracy ((TP + TN) / (P + N)): 0.9988200088251727
#  SARS-N2_POS  SARS-N1_POS  IBV-M_POS  RSV-N_POS  IAV-M_POS  MHV_POS
#     0.999543     0.999014   0.999348   0.995559   0.999867 0.999588
#
# F1 (2 * (precision * recall) / (precision + recall)): 0.9933850150967166
#  SARS-N2_POS  SARS-N1_POS  IBV-M_POS  RSV-N_POS  IAV-M_POS  MHV_POS
#     0.997237     0.994226   0.996355   0.977225   0.999284  0.99764
#
# Balanced Accuracy (Specificity + Recall) / 2: 0.9943310002822181
#  SARS-N2_POS  SARS-N1_POS  IBV-M_POS  RSV-N_POS  IAV-M_POS  MHV_POS
#     0.998095     0.996849   0.998194   0.977949   0.999383 0.997677

# %%
validation_lib.validate_combinations(df_di, df_decision, verbosity=0)
# Out:
# Total number of outlayer: 0
#
# Label combination ('SARS-N2_POS',):
# n outliers: 0, n_true_pos: 7801
# Balanced Accuracy: 0.9980094853623933
#
# Label combination ('SARS-N1_POS',):
# n outliers: 0, n_true_pos: 8393
# Balanced Accuracy: 0.9961491427116747
#
# Label combination ('IBV-M_POS',):
# n outliers: 0, n_true_pos: 10190
# Balanced Accuracy: 0.9980727246766752
#
# Label combination ('RSV-N_POS',):
# n outliers: 0, n_true_pos: 9527
# Balanced Accuracy: 0.9166164724196977
#
# Label combination ('IAV-M_POS',):
# n outliers: 0, n_true_pos: 5741
# Balanced Accuracy: 0.9979986366914682
#
# Label combination ('MHV_POS',):
# n outliers: 0, n_true_pos: 9144
# Balanced Accuracy: 0.9968391126184606
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS'):
# n outliers: 0, n_true_pos: 4267
# Balanced Accuracy: 0.9993610445708261
#
# Label combination ('SARS-N2_POS', 'IBV-M_POS'):
# n outliers: 0, n_true_pos: 1035
# Balanced Accuracy: 0.9985405383974755
#
# Label combination ('SARS-N2_POS', 'RSV-N_POS'):
# n outliers: 0, n_true_pos: 1253
# Balanced Accuracy: 0.9956466796669488
#
# Label combination ('SARS-N2_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 985
# Balanced Accuracy: 0.9969717281138503
#
# Label combination ('SARS-N2_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1159
# Balanced Accuracy: 0.9943881930104637
#
# Label combination ('SARS-N1_POS', 'IBV-M_POS'):
# n outliers: 0, n_true_pos: 1141
# Balanced Accuracy: 0.9947931028054087
#
# Label combination ('SARS-N1_POS', 'RSV-N_POS'):
# n outliers: 0, n_true_pos: 1366
# Balanced Accuracy: 0.9978082736631249
#
# Label combination ('SARS-N1_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 1084
# Balanced Accuracy: 0.9990709746501212
#
# Label combination ('SARS-N1_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1181
# Balanced Accuracy: 0.9945458428286575
#
# Label combination ('IBV-M_POS', 'RSV-N_POS'):
# n outliers: 0, n_true_pos: 2302
# Balanced Accuracy: 0.997394733583261
#
# Label combination ('IBV-M_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 1792
# Balanced Accuracy: 0.9991427494861451
#
# Label combination ('IBV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1327
# Balanced Accuracy: 0.9973578185920602
#
# Label combination ('RSV-N_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 2236
# Balanced Accuracy: 0.9942518441974724
#
# Label combination ('RSV-N_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1805
# Balanced Accuracy: 0.9934359523786681
#
# Label combination ('IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1464
# Balanced Accuracy: 0.9949248952488225
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IBV-M_POS'):
# n outliers: 0, n_true_pos: 768
# Balanced Accuracy: 0.9948443345985045
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'RSV-N_POS'):
# n outliers: 0, n_true_pos: 857
# Balanced Accuracy: 0.9982393915023555
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 951
# Balanced Accuracy: 0.9989404160648143
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 878
# Balanced Accuracy: 0.9943313902681397
#
# Label combination ('SARS-N2_POS', 'IBV-M_POS', 'RSV-N_POS'):
# n outliers: 0, n_true_pos: 532
# Balanced Accuracy: 0.9990547336933931
#
# Label combination ('SARS-N2_POS', 'IBV-M_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 787
# Balanced Accuracy: 0.9968311192241625
#
# Label combination ('SARS-N2_POS', 'IBV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 329
# Balanced Accuracy: 0.9102162354068233
#
# Label combination ('SARS-N2_POS', 'RSV-N_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 931
# Balanced Accuracy: 0.9941582790830419
#
# Label combination ('SARS-N2_POS', 'RSV-N_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 496
# Balanced Accuracy: 0.9412790872386525
#
# Label combination ('SARS-N2_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 754
# Balanced Accuracy: 0.9760049697104043
#
# Label combination ('SARS-N1_POS', 'IBV-M_POS', 'RSV-N_POS'):
# n outliers: 0, n_true_pos: 573
# Balanced Accuracy: 0.9922659896015495
#
# Label combination ('SARS-N1_POS', 'IBV-M_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 813
# Balanced Accuracy: 0.9879890400013731
#
# Label combination ('SARS-N1_POS', 'IBV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 418
# Balanced Accuracy: 0.9916560042110134
#
# Label combination ('SARS-N1_POS', 'RSV-N_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 989
# Balanced Accuracy: 0.9949857547296146
#
# Label combination ('SARS-N1_POS', 'RSV-N_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 513
# Balanced Accuracy: 0.9407144687600626
#
# Label combination ('SARS-N1_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 844
# Balanced Accuracy: 0.9993467017281681
#
# Label combination ('IBV-M_POS', 'RSV-N_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 1858
# Balanced Accuracy: 0.9977854088986403
#
# Label combination ('IBV-M_POS', 'RSV-N_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 953
# Balanced Accuracy: 0.996802958404551
#
# Label combination ('IBV-M_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1480
# Balanced Accuracy: 0.9939745175821959
#
# Label combination ('RSV-N_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1895
# Balanced Accuracy: 0.9924625888136588
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IBV-M_POS', 'RSV-N_POS'):
# n outliers: 0, n_true_pos: 539
# Balanced Accuracy: 0.9917667804970451
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IBV-M_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 952
# Balanced Accuracy: 0.9957645501993684
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IBV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 425
# Balanced Accuracy: 0.9775229622399796
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'RSV-N_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 1181
# Balanced Accuracy: 0.9957833593676295
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'RSV-N_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 582
# Balanced Accuracy: 0.9723943902878496
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 982
# Balanced Accuracy: 0.9959421424475386
#
# Label combination ('SARS-N2_POS', 'IBV-M_POS', 'RSV-N_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 1085
# Balanced Accuracy: 0.9945182149968521
#
# Label combination ('SARS-N2_POS', 'IBV-M_POS', 'RSV-N_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 514
# Balanced Accuracy: 0.9867362700175488
#
# Label combination ('SARS-N2_POS', 'IBV-M_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 953
# Balanced Accuracy: 0.9978906302964625
#
# Label combination ('SARS-N2_POS', 'RSV-N_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1206
# Balanced Accuracy: 0.9866786999072141
#
# Label combination ('SARS-N1_POS', 'IBV-M_POS', 'RSV-N_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 1099
# Balanced Accuracy: 0.9888779765989716
#
# Label combination ('SARS-N1_POS', 'IBV-M_POS', 'RSV-N_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 502
# Balanced Accuracy: 0.9817648092434044
#
# Label combination ('SARS-N1_POS', 'IBV-M_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 930
# Balanced Accuracy: 0.9879307904532566
#
# Label combination ('SARS-N1_POS', 'RSV-N_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1185
# Balanced Accuracy: 0.991681729331338
#
# Label combination ('IBV-M_POS', 'RSV-N_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 2192
# Balanced Accuracy: 0.9947937166846818
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IBV-M_POS', 'RSV-N_POS', 'IAV-M_POS'):
# n outliers: 0, n_true_pos: 1299
# Balanced Accuracy: 0.9924174714915507
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IBV-M_POS', 'RSV-N_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 589
# Balanced Accuracy: 0.9867758336379422
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IBV-M_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1147
# Balanced Accuracy: 0.9880820251809813
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'RSV-N_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1509
# Balanced Accuracy: 0.9983199671213703
#
# Label combination ('SARS-N2_POS', 'IBV-M_POS', 'RSV-N_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1404
# Balanced Accuracy: 0.9954025682552754
#
# Label combination ('SARS-N1_POS', 'IBV-M_POS', 'RSV-N_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1458
# Balanced Accuracy: 0.9905777071348016
#
# Label combination ('SARS-N2_POS', 'SARS-N1_POS', 'IBV-M_POS', 'RSV-N_POS', 'IAV-M_POS', 'MHV_POS'):
# n outliers: 0, n_true_pos: 1703
# Balanced Accuracy: 0.9939053998534833
